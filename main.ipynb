# %%
import cv2
import utils
import matplotlib.pyplot as plt
# Out:
# <unknown>:351: SyntaxWarning: invalid escape sequence '\d'

# %%
img = cv2.imread("/local/data1/jakli758/threeclasses/accepted/patient_10_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_4.png")
img2 = cv2.imread("/local/data1/jakli758/threeclasses/accepted/patient_1_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_4.png",0)

# %%
plt.imshow(img)

# %%
plt.imshow(img2, cmap='gray')

# %%
img_pad = preprocessing.resize_with_pad(img, (128,128))
img_pad2 = preprocessing.resize_with_pad(img2, (128,128))

# %%
plt.imshow(img_pad)

# %%
plt.imshow(img_pad2,cmap='gray')

# %%
import os
def test_preprocess(path='/local/data1/jakli758/threeclasses/', new_shape=(128,128)):

    folders = ['accepted', 'rejected']
    
    for folder in folders:
        path_current = f'{path}{folder}'
        path_new = f'{path}{folder}_preprocessed'
        for file in os.listdir(path_current):
            

            # imread automatically converts img to 8-bit, if CV.IMREAD_ANYDEPTH is not set
            img = cv2.imread(f'{path_current}/{file}', 0)
            img_preprocessed = preprocessing.resize_with_pad(image=img,new_shape=new_shape, padding_color=0)
            plt.imshow(img_preprocessed, cmap='gray')
            print(f'{path_current}/{file}')
            print(f'{path_new}/{file}')
            #cv2.imwrite(f'{path_new}/{file}')
            break
        break

# %%
test_preprocess()
# Out:
# /local/data1/jakli758/threeclasses/accepted/patient_1076_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_2.png
# /local/data1/jakli758/threeclasses/accepted_preprocessed/patient_1076_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_2.png

# %%
preprocessing.preprocess(path='/local/data1/jakli758/threeclasses/', new_shape=(256,256))
# Out:
# ...
# 100%|██████████| 1414/1414 [01:51<00:00, 12.66it/s]

# %%
preprocessing.preprocess(path='/local/data1/jakli758/threeclasses/', new_shape=(512,512))
# Out:
# ...
# 100%|██████████| 1414/1414 [02:14<00:00, 10.50it/s]

# %%
img3 = cv2.imread("/local/data1/jakli758/threeclasses/rejected/patient_5_AFF_class_1_modality_CR_scanoccasion_0_imagenumber_3.png", 0)

# %%
plt.imshow(img3, cmap='gray')

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/first_cyclegan/web/images/epoch004_fake_A.png",0)

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/more_epochs/web/images/epoch400_fake_A.png",0)

# %%
plt.imshow(img, cmap="grey")

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/more_epochs/web/images/epoch400_real_B.png",0)
plt.imshow(img,cmap='gray')

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/more_epochs/web/images/epoch400_rec_B.png",0)
plt.imshow(img,cmap='gray')

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/more_epochs/web/images/epoch400_idt_A.png", 0)
plt.imshow(img,cmap='gray')

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/more_epochs/web/images/epoch400_real_A.png")
plt.imshow(img,cmap='gray')

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/more_epochs/web/images/epoch400_fake_B.png", 0)
plt.imshow(img,cmap='gray')

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/0216_no_preprocessing/web/images/epoch123_fake_A.png", 0)
plt.imshow(img,cmap='gray')

# %%
img = cv2.imread("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/checkpoints/0216_no_preprocessing/web/images/epoch400_real_B.png", 0)
plt.imshow(img,cmap='gray')

# %%
utils.datasplit_dm()
# Out:
# <unknown>:289: SyntaxWarning: invalid escape sequence '\d'
# <unknown>:317: SyntaxWarning: invalid escape sequence '\d'
# Patient distribution:
# Train: Counter({'CONTROL': 758, 'AFF': 206})
# Val: Counter({'CONTROL': 85, 'AFF': 23})
# Test:  Counter({'CONTROL': 94, 'AFF': 26})
#
# File distribution per split:
#
# TRAIN:
#   AFF     : 952
#   CONTROL : 3689
#   HEALTHY : 0
#   TOTAL   : 4641
#
# VAL:
#   AFF     : 110
#   CONTROL : 397
#   HEALTHY : 0
#   TOTAL   : 507
#
# TEST:
#   AFF     : 177
#   CONTROL : 422
#   HEALTHY : 0
#   TOTAL   : 599
#
# GRAND TOTAL: 5747
#
#
# Dataset successfully created at: /local/data1/jakli758/dataset_new/dm/128/

# %%
from utils import datasplit_gan

# %%
from utils import datasplit_gan
datasplit_gan()
# Out:
# Start datasplit GAN
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 datasplit_gan()
#
# File /local/data1/jakli758/thesis_code/utils.py:47, in datasplit_gan(path, img_size)
#      42             img_preprocessed = resize_with_pad(image=img,new_shape=new_shape, padding_color=0)
#      44             cv2.imwrite(f'{path_new}/{file}', img_preprocessed)
# ---> 47 # https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
#      48 def resize_with_pad(image: np.array,
#      49                     new_shape: Tuple[int, int],
#      50                     padding_color: Tuple[int] = (0, 0, 0)) -> np.array:
#      51     """Maintains aspect ratio and resizes with padding.
#      52     Params:
#      53         image: Image to be resized.
#    (...)     57         image: Resized image with padding
#      58     """
#
# ...
