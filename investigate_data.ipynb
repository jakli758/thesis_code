# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import cv2
import utils
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
utils.plot_img("/local/data1/jakli758/dataset_normalized/gan/raw_gray/train_HEALTHY/patient_427_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_4.png")

# %%
utils.plot_img("/local/data1/jakli758/dataset_normalized/gan/raw/train_HEALTHY/patient_427_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_4.png",0)

# %%
utils.plot_img("/local/data1/jakli758/threeclasses/rejected/patient_427_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_4.png",0)

# %%
img = cv2.imread("/local/data1/jakli758/accepted_anonymized_hospitalinfo_8bit_Sept15_2023/patient_YRLVNORJGP_hospital_48_NFF_image_3.png", 0)
plt.imsave("./data_examples/hospital_48_NFF.png",img, cmap="gray")

# %%
utils.plot_img("/local/data1/jakli758/dataset_normalized/gan/raw_gray/train_AFF/patient_5_AFF_class_1_modality_CR_scanoccasion_0_imagenumber_2.png")

# %%
utils.plot_img("/local/data1/jakli758/threeclasses/accepted/patient_5_AFF_class_1_modality_CR_scanoccasion_0_imagenumber_2.png",0)

# %%
img = cv2.imread("/local/data1/jakli758/threeclasses/accepted/patient_5_AFF_class_1_modality_CR_scanoccasion_0_imagenumber_2.png",-1)

# %%
plt.imshow(img, cmap="gray")

# %%
img = cv2.imread("/local/data1/jakli758/threeclasses/accepted/patient_19_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_3.png",-1)

# %%
plt.imshow(img,cmap="gray")

# %%
utils.plot_img("/local/data1/jakli758/threeclasses/accepted/patient_19_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_3.png",0)

# %% [markdown]
# ## Plot histogram of horses/zebras

# %%
utils.plot_intensity_histogram("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/datasets/horse2zebra/trainA")

# %%
utils.plot_folder_histograms("/local/data1/jakli758/thesis_code/pytorch-CycleGAN-and-pix2pix/datasets/horse2zebra/trainA")

# %% [markdown]
# ### Plot histograms per hospital

# %%
path = "/local/data1/jakli758/accepted_anonymized_hospitalinfo_8bit_Sept15_2023/"

# %%
p = os.path.join(path, "1", "NFF")
utils.plot_intensity_histogram(p)

# %%
p = os.path.join(path, "2", "AFF")
utils.plot_intensity_histogram(p)

# %%
p = os.path.join(path, "3", "NFF")
utils.plot_intensity_histogram(p)

# %%
p = os.path.join(path, "3", "AFF")
utils.plot_intensity_histogram(p)

# %%
p = os.path.join(path, "4", "NFF")
utils.plot_intensity_histogram(p)

# %%
p = os.path.join(path, "5", "NFF")
utils.plot_intensity_histogram(p)

# %%
p = os.path.join(path, "5", "AFF")
utils.plot_intensity_histogram(p)

# %%
p = os.path.join(path, "6", "AFF")
utils.plot_intensity_histogram(p)

# %%
p = os.path.join(path, "6", "NFF")
utils.plot_intensity_histogram(p)
