# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import plot_cyclegan_losses

# %%
plot_cyclegan_losses("pytorch-CycleGAN-and-pix2pix/run_output_zebra.txt")
# Out:
#       epoch  iters    D_A    G_A  ...    G_B  cycle_B  idt_B  log_index
# 0         1    200  0.394  0.711  ...  0.332    0.759  0.259          1
# 1         1    400  0.232  0.442  ...  0.497    0.935  0.295          2
# 2         1    600  0.172  0.798  ...  0.490    0.765  0.269          3
# 3         1    800  0.218  0.526  ...  0.304    0.687  0.260          4
# 4         1   1000  0.187  0.672  ...  0.657    1.100  0.247          5
# ...     ...    ...    ...    ...  ...    ...      ...    ...        ...
# 1331    200    536  0.155  0.656  ...  0.389    0.599  0.154       1332
# 1332    200    736  0.172  0.515  ...  0.436    0.548  0.160       1333
# 1333    200    936  0.147  0.512  ...  0.483    0.606  0.149       1334
# 1334    200   1136  0.164  0.610  ...  0.407    0.523  0.158       1335
# 1335    200   1336  0.125  0.448  ...  0.468    0.529  0.152       1336
#
# [1336 rows x 11 columns]

# %%
plot_cyclegan_losses("pytorch-CycleGAN-and-pix2pix/run_output_0302_hel2nff.txt")

# %%
plot_cyclegan_losses("pytorch-CycleGAN-and-pix2pix/run_output_0303_hel2nff_raw.txt")

# %%
plot_cyclegan_losses("pytorch-CycleGAN-and-pix2pix/run_output_03012_hel2nff_raw_cl2_noprep.txt")

# %%
from utils import plot_img

# %%
plot_img("/local/data2/jakli758/data_raw/gan/128/trainB/patient_476_CONTROL_class_1_modality_CR_scanoccasion_0_imagenumber_3.png")
